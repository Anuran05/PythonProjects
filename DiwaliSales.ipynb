# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df=pd.read_csv(r"C:\Users\user\Desktop\Diwali.csv") #The code ran without errors. This is because the default encoding of the CSV file was changed to UTF-8 before opening it with pandas. Since the default encoding used by pandas is UTF-8, the CSV file opened without error. 
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info() #User_ID column has 11251 rows but Status column has 0 rows which doesn't make sense so we need to delete it
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True) #axis=1 implies that we should remove a column 
# we use inplace=True to delete the column without having to reassign df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
df.isnull() #isnull() method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False.
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
df.isnull().sum()#To find the number of missing (NaN) values in each column, use the isnull() function followed by sum().
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.dropna(inplace=True) #Deletes all null values from the original dataset

# %%
df.shape #12 null values in Amount column got deleted
# Out:
# (11239, 13)

# %%
#Understanding significance of inplace=True 
data_test=[['Rony',10],['Bony',12],['Tony',]] #Initialize list of lists
df_test=pd.DataFrame(data_test,columns=['Name','Age']) #Create the pandas Dataframe using list
df_test
# Out:
#    Name   Age
# 0  Rony  10.0
# 1  Bony  12.0
# 2  Tony   NaN

# %%
#df_test.dropna() #Original dataframe df_test has not been changed
df_test.dropna(inplace=True) #Original dataframe df_test has been changed
df_test

#df_test=df_test.dropna() and df_test.dropna(inplace=True) are the same
# Out:
#    Name   Age
# 0  Rony  10.0
# 1  Bony  12.0

# %%
df['Amount']=df['Amount'].astype('int') #Changes values in Amount coloumn to integer
df['Amount'].dtypes #Previously it was float64 and now it will be int64
# Out:
# dtype('int64')

# %%
#Rename a particular column
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#We will change the name of the Amount column to Total Amount
df.rename(columns={'Amount':'Total Amount'}) #Dictionary format
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe() #describe() method is a powerful tool to generate descriptive statistics of a DataFrame. It provides a comprehensive summary, including count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#df['Age'].describe() Describes a particular column
df[['Age','Orders']].describe() #Describes multiple columns
# Out:
#                 Age        Orders
# count  11239.000000  11239.000000
# mean      35.410357      2.489634
# std       12.753866      1.114967
# min       12.000000      1.000000
# 25%       27.000000      2.000000
# 50%       33.000000      2.000000
# 75%       43.000000      3.000000
# max       92.000000      4.000000

# %%
#Exploratory Data Analysis
ax=sns.countplot(x='Gender',data=df)
for bars in ax.containers: #ax is a plot object and it contains a method called containers that lists the properties of each bar Iterate through the list items of the container object and pass each item to the bar_label function. This will extract and display the bar value in the bar plot.
    ax.bar_label(bars)

# %%
df.groupby(['Gender'],as_index=False).sum().sort_values(by='Amount',ascending=False) #Groups by gender
# Out:
#   Gender     User_ID                                          Cust_name  \
# 0      F  7855372419  SanskritiKartikBinduBalkGinnyKargatisElijahLau...
# 1      M  3417384162  SudeviJoniJoniKushalHarshitaVasudevPraneetPran...
#
#                                           Product_ID  \
# 0  P00125942P00110942P00118542P00018042P00031142P...
# 1  P00237842P00057942P00057942P00205642P00200842P...
#
#                                            Age Group     Age  Marital_Status  \
# 0  26-3526-3526-3518-2526-3518-2518-2518-2526-351...  276660            3259
# 1  0-1726-3526-3526-3526-3526-3551-5551-5555+51-5...  121317            1462
#
#                                                State  \
# 0  MaharashtraAndhra PradeshUttar PradeshUttar Pr...
# 1  KarnatakaGujaratHimachal PradeshUttar PradeshD...
#
#                                                 Zone  \
# 0  WesternSouthernCentralCentralSouthernSouthernS...
# 1  SouthernWesternNorthernCentralCentralSouthernC...
#
# ...

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df=pd.read_csv(r"C:\Users\user\Desktop\Diwali.csv")
ax=sns.countplot(data=df,x='Age Group',hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Age Group',y='Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
#Number of orders from top 10 states 
sales_state=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State',y='Orders',data=sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
#Number of sales amount from top 10 states
sales_state=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State',y='Amount',data=sales_state)

#From the graphs we can conclude that Haryana has a higher purchasing power because even though the number of orders from Haryana is lesser than that of 
#Kerala, sales amount collected from Haryana.
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
ax=sns.countplot(data=df,x='Marital_Status')
sns.set(rc={'figure.figsize':(5,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state=df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marital_Status',y='Amount',hue='Gender',data=sales_state)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
ax=sns.countplot(data=df,x='Occupation')
sns.set(rc={'figure.figsize':(2,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x='Occupation',y='Amount',data=sales_state)
#From the graph we can see most buyers are from IT sector
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
ax=sns.countplot(data=df,x='Product_Category')
sns.set(rc={'figure.figsize':(10,60)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state=df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(3)
sns.set(rc={'figure.figsize':(10,4)})
sns.barplot(x='Product_Category',y='Amount',data=sales_state)
#From the graph it is clear that people spend the most on food followed by clothes
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
#Top 3 most sold products 
sales_state=df.groupby(['Product_ID'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(3)
sns.set(rc={'figure.figsize':(10,4)})
sns.barplot(x='Product_ID',y='Amount',data=sales_state)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Amount'>

# %%
#CONCLUSION 
#Married women from the age group 26-35 years from UP working in IT sector spends the most on Food items.
